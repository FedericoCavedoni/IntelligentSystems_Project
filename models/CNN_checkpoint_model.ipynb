# %% [markdown]
# **FIRST MODEL WITH TWO CONV-POOLING LAYERS, WITHOUT DROPOUT AND WITHOUT EARLY STOPPING**

# %%
model = Sequential()

# Conv and Pooling layers
model.add(layers.Conv1D(32, 3, activation='relu', input_shape=(time_steps, num_features)))
model.add(layers.MaxPooling1D(2))
model.add(layers.Conv1D(32, 3, activation='relu', input_shape=(time_steps, num_features)))
model.add(layers.MaxPooling1D(2))

# Flattening
model.add(layers.Flatten())

# Dense layer
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(5, activation='softmax'))

# compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train_scaled, y_train, validation_split=0.1, batch_size=10, epochs=20, verbose=1, shuffle = True)
